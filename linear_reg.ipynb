# %%
# imports
from sklearn.datasets import make_regression
from matplotlib import pyplot as plt
import numpy as np

# custom file imports
from model import LinearRegressionModel

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ##### Generating Fake Data

# %%
X, y = make_regression(n_samples=200, n_features=1, n_informative=1, noise=6, bias=30, random_state=45667566)

# %% [markdown]
# ##### Visualizing the Data

# %%
plt.scatter(X, y, c = "red",alpha=.5, marker = 'o')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ### Training the model

# %%
linear_regression = LinearRegressionModel(max_iter=500)
linear_regression.fit(X, y)
# Out:
# Loss from cost function: 3296.414727549994, Weights: [-0.22387533  1.48750376]  Gradidents: [-35.50299146 -73.43415371]
# Loss from cost function: 661.9392565462607, Weights: [18.25152318 41.80788179]  Gradidents: [-14.13157538 -33.17206503]
# Loss from cost function: 145.35817220129493, Weights: [25.55442432 60.046287  ]  Gradidents: [ -5.52939356 -15.03084401]
# Loss from cost function: 43.05059352677914, Weights: [28.38534794 68.32173887]  Gradidents: [-2.11383443 -6.83191275]
# Loss from cost function: 22.567073672651013, Weights: [29.45352959 72.0883186 ]  Gradidents: [-0.78179065 -3.11496145]
# Loss from cost function: 18.41793496531537, Weights: [29.84097752 73.80801917]  Gradidents: [-0.27488875 -1.42465405]
# Loss from cost function: 17.56719653362419, Weights: [29.97294634 74.59560885]  Gradidents: [-0.0886737  -0.65358071]
# array([29.98747926, 74.70844863])

# %% [markdown]
# ## Visualizing the Result

# %%
w = linear_regression.weights

def graph(formula, x_range):  
    x = np.array(x_range)  
    y = formula(x)  
    plt.plot(x, y)  
    
def my_formula(x):
    return w[0]+w[1]*x

plt.scatter(X,y, c = "red",alpha=.5, marker = 'o')
graph(my_formula, range(-5,5))
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
