# %%
# imports
from sklearn.datasets import make_regression
from matplotlib import pyplot as plt
import numpy as np

# custom file imports
from model import LinearRegressionModel

# %%
# %load_ext autoreload

# %% [markdown]
# ##### Generating Fake Data

# %%
X, y = make_regression(n_samples=200, n_features=1, n_informative=1, noise=6, bias=30, random_state=200)

# %% [markdown]
# ##### Visualizing the Data

# %%
plt.scatter(X, y, c = "red",alpha=.5, marker = 'o')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ### Training the model

# %%
linear_regression = LinearRegressionModel(max_iter=10000000)
linear_regression.fit(X, y)
# Out:
# Loss from cost function: 21190697.121910665, Weights: [ 0.61594802 -0.77837956]
# Loss from cost function: 3303915.672566343, Weights: [19.63597269  5.73303693]
# Loss from cost function: 1078853.4574324528, Weights: [26.43279654  7.75916315]
# Loss from cost function: 800035.3418121841, Weights: [28.87018609  8.36468312]
# Loss from cost function: 764759.9922640156, Weights: [29.74768846  8.53411639]
# Loss from cost function: 760241.3574095323, Weights: [30.06498326  8.57597628]
# array([30.14738197,  8.58218312])

# %% [markdown]
# ## Visualizing the Result

# %%
w = linear_regression.weights

def graph(formula, x_range):  
    x = np.array(x_range)  
    y = formula(x)  
    plt.plot(x, y)  
    
def my_formula(x):
    return w[0]+w[1]*x

plt.scatter(X,y, c = "red",alpha=.5, marker = 'o')
graph(my_formula, range(-5,5))
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
